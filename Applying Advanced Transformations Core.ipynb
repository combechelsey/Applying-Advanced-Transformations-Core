# %% [markdown]
# 1. Clean the files and combine them into one final DataFrame.
#
# This dataframe should have the following columns:
#    - Hero (Just the name of the Hero)
#
#    - Publisher
#
#    - Gender
#
#    - Eye color
#
#    - Race
#
#    - Hair color
#
#    - Height (numeric)
#
#    - Skin color
#
#    - Alignment
#
#    - Weight (numeric)
#
#     **Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:**
#
#    - Agility
#
#    - Flight
#
#    - Superspeed
#
#    - etc.
# Hint: There is a space in "100 kg" or "52.5 cm"
#
#
#
# 2. Use your combined DataFrame to answer the following questions.
#
# - Compare the average weight of super powers who have Super Speed to those who do not.
#
# - What is the average height of heroes for each publisher?

# %%
# Imports
import numpy as np
import pandas as pd
import json

# %%
# Make Data folder
import os
os.makedirs('Data/',exist_ok=True) # Confirm folder created
os.listdir("Data/")
# Out:
# ['superhero_info - superhero_info.csv',
#  'superhero_powers - superhero_powers.csv']

# %%
# Load datasets
info = pd.read_csv('Data/superhero_info - superhero_info.csv')
powers = pd.read_csv('Data/superhero_powers - superhero_powers.csv')

# %%
# Display first five rows of both datasets
display(info.head(), powers.head())
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# ## Clean Data
#
# ### Split Hero|Publisher column

# %%
# Split Hero and Publisher into two columns
info[["Hero", "Publisher"]]  = info["Hero|Publisher"].str.split('|', expand = True)
# Drop Hero|Publisher column
info.drop(columns = 'Hero|Publisher', inplace = True)
info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %% [markdown]
# ## Split Height and Weight

# %%
# Import ast to convert he strings to python dictionaries
import ast

# Converting Measurements strings to dictionaries
info['Measurements'] = info['Measurements'].apply(ast.literal_eval)

# Split Measurements into two columns
info['Height'] = info['Measurements'].apply(lambda x: x['Height'])
info['Weight'] = info['Measurements'].apply(lambda x: x['Weight'])

# Remove the original Measurements column
info.drop(columns = 'Measurements', inplace = True)

info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %% [markdown]
# ## Remove cm and kg from height and weight columns

# %%
# Remove 'cm' and 'kg' from 'Height' and 'Weight' columns
info['Height'] = info['Height'].str.replace(' cm', '').astype(float)
info['Weight'] = info['Weight'].str.replace(' kg', '').astype(float)

# %% [markdown]
# ## Split Power Column

# %%
### Get a list of all powers
possible_powers = powers['Powers'].str.split(',').explode().value_counts().index
possible_powers
# Out:
# Index(['Super Strength', 'Stamina', 'Durability', 'Super Speed', 'Agility',
#        'Flight', 'Accelerated Healing', 'Reflexes', 'Intelligence',
#        'Energy Blasts',
#        ...
#        'Omnitrix', 'Thirstokinesis', 'Anti-Gravity', 'Hyperkinesis',
#        'Speed Force', 'Electrical Transport', 'Molecular Dissipation',
#        'Banish', 'Biokinesis', 'Changing Armor'],
#       dtype='object', name='Powers', length=167)

# %%
# OHE power column
for col in possible_powers:
    powers[col] = powers['Powers'].str.contains(col)
    
# Remove the original Powers column
powers.drop(columns = 'Powers', inplace = True)

# Display new powers dataframe
powers.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20736\3743024926.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers['Powers'].str.contains(col)
#     hero_names  Super Strength  Stamina  Durability  Super Speed  Agility  \
# 0      3-D Man            True     True       False         True     True
# 1       A-Bomb            True     True        True        False    False
# 2   Abe Sapien            True     True        True        False     True
# 3     Abin Sur           False    False       False        False    False
# 4  Abomination            True     True       False         True    False
#
#    Flight  Accelerated Healing  Reflexes  Intelligence  ...  Omnitrix  \
# 0   False                False     False         False  ...     False
# 1   False                 True     False         False  ...     False
# 2   False                 True      True          True  ...     False
# 3   False                False     False         False  ...     False
# 4   False                 True     False          True  ...     False
#
#    Thirstokinesis  Anti-Gravity  Hyperkinesis  Speed Force  \
# 0           False         False         False        False
# 1           False         False         False        False
# 2           False         False         False        False
# 3           False         False         False        False
# 4           False         False         False        False
#
#    Electrical Transport  Molecular Dissipation  Banish  Biokinesis  \
# 0                 False                  False   False       False
# 1                 False                  False   False       False
# 2                 False                  False   False       False
# 3                 False                  False   False       False
# 4                 False                  False   False       False
#
#    Changing Armor
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 168 columns]

# %% [markdown]
# ## Merge Dataframes

# %%
# Merge info and powers
df = pd.merge(info, powers, left_on = 'Hero', right_on = 'hero_names')

# Set Hero to index
df = df.set_index('Hero')

df.head()
# Out:
#               Gender               Race Alignment Hair color Eye color  \
# Hero
# A-Bomb          Male              Human      good    No Hair    yellow
# Abe Sapien      Male      Icthyo Sapien      good    No Hair      blue
# Abin Sur        Male            Ungaran      good    No Hair      blue
# Abomination     Male  Human / Radiation       bad    No Hair     green
# Absorbing Man   Male              Human       bad    No Hair      blue
#
#               Skin color          Publisher  Height  Weight     hero_names  \
# Hero
# A-Bomb           Unknown      Marvel Comics   203.0   441.0         A-Bomb
# Abe Sapien          blue  Dark Horse Comics   191.0    65.0     Abe Sapien
# Abin Sur             red          DC Comics   185.0    90.0       Abin Sur
# Abomination      Unknown      Marvel Comics   203.0   441.0    Abomination
# Absorbing Man    Unknown      Marvel Comics   193.0   122.0  Absorbing Man
#
#                ...  Omnitrix  Thirstokinesis  Anti-Gravity  Hyperkinesis  \
# Hero           ...
# A-Bomb         ...     False           False         False         False
# Abe Sapien     ...     False           False         False         False
# Abin Sur       ...     False           False         False         False
# Abomination    ...     False           False         False         False
# Absorbing Man  ...     False           False         False         False
#
#                Speed Force  Electrical Transport  Molecular Dissipation  \
# Hero
# A-Bomb               False                 False                  False
# Abe Sapien           False                 False                  False
# Abin Sur             False                 False                  False
# Abomination          False                 False                  False
# Absorbing Man        False                 False                  False
#
#                Banish  Biokinesis  Changing Armor
# Hero
# A-Bomb          False       False           False
# Abe Sapien      False       False           False
# Abin Sur        False       False           False
# Abomination     False       False           False
# Absorbing Man   False       False           False
#
# [5 rows x 177 columns]

# %% [markdown]
# # Questions:
#
# ## Compare the average weight of super powers who have Super Speed to those who do not.

# %%
# Create filter for super speed
speed_filter = df["Super Speed"]

# Calculate avererage weight of each superhero group
ave_weight_with = round(df.loc[speed_filter, 'Weight'].mean(), 2)
ave_weight_without = round(df.loc[~speed_filter, 'Weight'].mean(), 2)

print(f'The average weight of heros with super speed abilities is {ave_weight_with} kg.')
print(f'The average weight of heros without super speed abilities is {ave_weight_without} kg.')
# Out:
# The average weight of heros with super speed abilities is 129.4 kg.
# The average weight of heros without super speed abilities is 101.77 kg.

# %% [markdown]
# ## What is the average height of heroes for each publisher?

# %%
df.groupby('Publisher')['Height'].mean().round(2).sort_values(ascending = False)
# Out:
# Publisher
# Image Comics         211.00
# Marvel Comics        191.55
# DC Comics            181.92
# Star Trek            181.50
# Team Epic TV         180.75
# Unknown              178.00
# Dark Horse Comics    176.91
# Shueisha             171.50
# George Lucas         159.60
# Name: Height, dtype: float64
